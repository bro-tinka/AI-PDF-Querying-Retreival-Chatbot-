# %%
import tensorflow
from tensorflow import keras

# %%
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
# Out:
# WARNING:tensorflow:From c:\Users\tinka001\anaconda3\envs\env_chatbot\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from collections import deque

class MyChatbot:
    def __init__(self, model_name='all-MiniLM-L6-v2'):
        self.model = SentenceTransformer(model_name)
        self.index = None
        self.corpus = []
        self.history = deque(maxlen=2)  # Store only last 2 queries
        self.history_embeddings = deque(maxlen=2)

    def ingest_text(self, text_list):
        """Builds the search index from provided text strings."""
        self.corpus = text_list
        embeddings = self.model.encode(self.corpus,normalize_embeddings=True)
        self.index = faiss.IndexFlatIP(embeddings.shape[1])
        self.index.add(embeddings.astype('float32'))

    def retrieve(self, user_query, top_k=2):
        # 1. Get embedding for the current query
        current_vec = self.model.encode([user_query],normalize_embeddings=True)[0]
        
        if not self.history:
            final_vec = current_vec
        else:
            # 2. Get average embedding of the history (last 2 queries)
            avg_history_vec = np.mean(self.history_embeddings, axis=0)
            #   high context for shorter queries : why, how , explain etc
            if len(user_query.split()) <= 3:
                final_vec = 0.6 * current_vec + 0.4 * avg_history_vec
            else:
                final_vec = 0.8 * current_vec + 0.2 * avg_history_vec

            final_vec /= np.linalg.norm(final_vec)
            
        # 4. Search with the weighted final vector "final_vec"
        final_vec = np.array([final_vec]).astype('float32')
        distances, indices = self.index.search(final_vec, top_k)
        
        self.history.append(user_query)
        self.history_embeddings.append(current_vec)
        return [self.corpus[idx] for idx in indices[0] if idx != -1]

# %%
# --- Testing the Logic ---
bot1 = MyChatbot()
bot1.ingest_text([
    "The office is located in London.",
    "The London office manager is Alice.",
    "Alice's contact email is alice@company.com",
    "The Paris office is managed by Bob."
])

#Query 1
print("A:", bot1.retrieve("Where is the office?")[0])
# Query 2
print("A:", bot1.retrieve("Who is the manager there?")[0])
# Out:
# A: The office is located in London.
# A: The London office manager is Alice.

# %%
bot1.retrieve("who is manager there?")[0]
# Out:
# 'The London office manager is Alice.'

# %%
bot1.retrieve("what is his email?")[0]
# Out:
# "Alice's contact email is alice@company.com"

# %% [markdown]
# BUILDING A CHATBOT FOR LARGE TEXT  -> CHUNKING

# %%
with open("text.txt", "r", encoding="utf-8") as f:
    text = f.read()      # whole file as one string

# %%
#NO OF WORD COUNT 
len(text.strip().split())
# Out:
# 586

# %%
bot = MyChatbot()
bot.ingest_text(text)
#will show error -> feed chunked_text
#token limit < 512 in "all-MiniLM-L6-v2"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 bot = MyChatbot()
# ----> 2 bot.ingest_text(text)
#       3 #will show error -> feed chunked_text
#       4 #token limit < 512 in "all-MiniLM-L6-v2"
#
# Cell In[12], line 16, in MyChatbot.ingest_text(self, text_list)
#      14 self.corpus = text_list
#      15 embeddings = self.model.encode(self.corpus,normalize_embeddings=True)
# ---> 16 self.index = faiss.IndexFlatIP(embeddings.shape[1])
#      17 self.index.add(embeddings.astype('float32'))
#
# IndexError: tuple index out of range

# %%
def chunk_text(text, chunk_size=30, overlap=6):
    words = text.split()
    chunks = []
    start = 0

    while start < len(words):
        end = start + chunk_size
        chunks.append(" ".join(words[start:end]))
        start = end - overlap

    return chunks

chunked_text = chunk_text(text)

# %%
for ss in chunked_text:
    print(ss)
# Out:
# A long time ago, there was a landlord. He had a big garden at the border of a forest. That garden was very special to him. But it was very
# to him. But it was very big, so he could not take care of it. So, he hired a gardener to take care of his garden. The gardener was very
# his garden. The gardener was very loyal to his employer. He was also very good at looking after the garden. When summer came, the gardener had to water the plants
# gardener had to water the plants every day without missing them. So, he did not get any holiday. But, he knew that if he took even one day off, the
# took even one day off, the plant would not get any water and would dry up. Whenever he approached his employer to give him a day off, he said, “I
# a day off, he said, “I do not see anyone else doing your work. So tell me, who will water the plants if you take a day off? I cannot
# take a day off? I cannot give you a holiday knowing there is no one else to water my plants.” Upon hearing his employer’s reply, the gardener was frightened and
# reply, the gardener was frightened and could not say anything to convince his employer to grant him a day’s leave. The same thing repeatedly happened whenever the gardener asked for
# happened whenever the gardener asked for a holiday from the landlord. One day, there was an annual temple festival at the gardener’s village. He wanted to take a day off
# wanted to take a day off and enjoy the festival with his family. But he could not ask the landlord to grant him a day’s leave. The gardener decided that
# day’s leave. The gardener decided that no matter what, he would enjoy this festival. So he made up a plan. He approached a group of monkeys living in a forest.
# of monkeys living in a forest. The gardener carefully went to the king of the monkeys and told him that he had come to ask for their help. “I am
# ask for their help. “I am a gardener at the landlord’s house living at the forest border. But he is cruel and does not let me take leave.” When the
# let me take leave.” When the monkeys nodded to acknowledge the landlord’s house, the gardener said, “Tomorrow, there is an annual temple festival in my village. But the landlord would
# my village. But the landlord would not let me take a day off. Can you please help me?” The monkey replied, “How can I or my subjects help you? We
# or my subjects help you? We are not gardeners.” The gardener told the monkey that all they needed to do was water the plants. “I will give you pots and
# “I will give you pots and vessels to all of you. Just take them to the nearby river, fill them with water, and water each plant.” The monkey king said
# each plant.” The monkey king said to the gardener, “Do not worry! You go and enjoy the annual festival with your family. We shall take care of the garden.” Hearing
# take care of the garden.” Hearing this, the gardener became very happy and relieved. He thought now he would be able to enjoy a day with his family members. But
# day with his family members. But the monkeys were confused about how much water to pour into each plant. So, they enquired about it to their king. The monkey king
# to their king. The monkey king said, “water each plant according to its roots.” When the monkeys asked how they could find the plants' roots, the king replied, “pull them
# roots, the king replied, “pull them out and water them.” On the festival day, the monkey removed all the plants and watered them. Once they finished watering the plants, they
# they finished watering the plants, they replanted them in a haphazard (organising something without following any principle) manner. The next morning, when the gardener was strolling in the garden, he
# was strolling in the garden, he saw that all the plants were drying up. Seeing that, he got so angry and dismissed the gardener. Moral Do not depend on anyone
# Moral Do not depend on anyone to do your work.

# %%
bot.ingest_text(chunked_text)

# %%
bot.retrieve("what did the gardener do at his employer's house?")[0]
# Out:
# 'to him. But it was very big, so he could not take care of it. So, he hired a gardener to take care of his garden. The gardener was very'

# %%
question = "whom did the gardener ask to water plants so that he can go to celebrate festival ?"
bot.retrieve(question)[0]
# Out:
# 'his garden. The gardener was very loyal to his employer. He was also very good at looking after the garden. When summer came, the gardener had to water the plants'

# %%
question = "what did monkey do?"
bot.retrieve(question)[0]
# Out:
# 'day with his family members. But the monkeys were confused about how much water to pour into each plant. So, they enquired about it to their king. The monkey king'

# %%
bot.retrieve(question)[1]
# Out:
# "to their king. The monkey king said, “water each plant according to its roots.” When the monkeys asked how they could find the plants' roots, the king replied, “pull them"
